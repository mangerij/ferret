# %%
import os
import subprocess
import numpy as np

size = 19

mat1 = 'PTO'
mat2 = 'STO'

file_directory = '/home/john/Hysteresis/'
output_file_directory = '/home/john/Hysteresis/test2/'


#construct the field pattern. Note that -10.0 = 


electrostatic_potential_vec1 = np.linspace(-10.0, 10.0, 51 );
electrostatic_potential_vec2 = np.linspace(10.0, -10.0, 51 );

electrostatic_potential_vec = np.concatenate((electrostatic_potential_vec1, electrostatic_potential_vec2), axis = 0)

#First file (index 0) is the solve on full TDLGD.
for t in range(0,len(electrostatic_potential_vec)):
    infile = open(file_directory +  repr(size) + '_' + mat1 + '_' + mat2 + '_Pole-def.i')
    outfile = open(output_file_directory+repr(size)+'_' + mat1 + '_' + mat2 + '_Pole-'+repr(t)+'.i', 'w')
    replacements = {
        'file = out_' + mat1 + 'sphere_in' + mat2 + '_'+repr(size)+'_defH.e':'file = out_' + mat1 + 'sphere_in' + mat2 + '_'+repr(size)+'_H'+repr(t)+'.e',
        'value = def':'value = %s' % electrostatic_potential_vec[t],
        'file_base = out_' + mat1 + 'sphere_in' + mat2 + '_'+repr(size)+'_def':'file_base = out_' + mat1 + 'sphere_in' + mat2 + '_'+repr(size)+'_'+repr(t)
    }
    for line in infile:
        for src, target in replacements.iteritems():
            line = line.replace(src, target)
        outfile.write(line)
    infile.close()
    outfile.close()
    
for k in range(0,len(electrostatic_potential_vec)-1):
    infile = open(file_directory+repr(size)+'_' + mat1 + '_' + mat2 + '_NoiseStep-def.i')
    outfile = open(output_file_directory+repr(size)+'_' + mat1 + '_' + mat2 + '_NoiseStep-'+repr(k+1)+'.i', 'w')
    replacements = {
        'file = out_' + mat1 + 'sphere_in' + mat2 + '_'+repr(size)+'_def.e':'file = out_' + mat1 + 'sphere_in' + mat2 + '_'+repr(size)+'_'+repr(k)+'.e',
        'file_base = out_' + mat1 + 'sphere_in' + mat2 + '_'+repr(size)+'_defH.e':'file_base = out_' + mat1 + 'sphere_in' + mat2 + '_'+repr(size)+'_H'+repr(k+1)
    }
    for line in infile:
        for src, target in replacements.iteritems():
            line = line.replace(src, target)
        outfile.write(line)
    infile.close()
    outfile.close()
    
    
#Make sure first file solves TDLGD with the original mesh.
infile = open(output_file_directory + repr(size) + '_' + mat1 + '_' + mat2 + '_Pole-0.i')
outfile = open(output_file_directory + repr(size) + '_' + mat1 + '_' + mat2 + '_Pole-0temp.i', 'w')
replacements = {
        "initial_from_file_timestep = 'LATEST'":"",
        "initial_from_file_var = polar_x":"[./InitialCondition]      type = RandomIC      min = -0.5e-5      max = 0.5e-5      seed = 1    [../]",
        "initial_from_file_var = polar_y":"[./InitialCondition]      type = RandomIC      min = -0.5e-5      max = 0.5e-5      seed = 1    [../]",
        "initial_from_file_var = polar_z":"[./InitialCondition]      type = RandomIC      min = -0.5e-5      max = 0.5e-5      seed = 1    [../]",
        "initial_from_file_var = potential_int":"[./InitialCondition]      type = RandomIC      min = -0.5e-5      max = 0.5e-5      seed = 1    [../]",
        "initial_from_file_var = disp_x":"",
        "initial_from_file_var = disp_y":"",
        "initial_from_file_var = disp_z":"",
        "initial_from_file_var = stress_xx_elastic":"",
        "initial_from_file_var = stress_xy_elastic":"",
        "initial_from_file_var = stress_xz_elastic":"",
        "initial_from_file_var = stress_yy_elastic":"",
        "initial_from_file_var = stress_yz_elastic":"",
        "initial_from_file_var = stress_zz_elastic":"",
        "initial_from_file_var = strain_xx_elastic":"",
        "initial_from_file_var = strain_xy_elastic":"",
        "initial_from_file_var = strain_xz_elastic":"",
        "initial_from_file_var = strain_yy_elastic":"",
        "initial_from_file_var = strain_yz_elastic":"",
        "initial_from_file_var = strain_zz_elastic":"",
        "initial_from_file_var = chern":"",
        'file = out_' + mat1 + 'sphere_in' + mat2 + '_'+repr(size)+'_H0.e':'file = embedded_single_sphere_'+repr(size)+'.e'
    }
for line in infile:
    for src, target in replacements.iteritems():
        line = line.replace(src, target)
    outfile.write(line)
infile.close()
outfile.close()

#remove and rename the first file.
os.remove(output_file_directory + repr(size) + '_' + mat1 + '_' + mat2 + '_Pole-0.i')

os.rename(output_file_directory + repr(size) + "_" + mat1 + "_" + mat2 + "_Pole-0temp.i",output_file_directory + repr(size) + "_" + mat1 + "_" + mat2 + "_Pole-0.i")

# %%
import numpy as np
electrostatic_potential_vec1 = np.linspace(-10.0, 10.0, 101 );
electrostatic_potential_vec2 = np.linspace(10.0, -10.0, 101 );


electrostatic_potential_vec = np.concatenate((electrostatic_potential_vec1, electrostatic_potential_vec2), axis=0)

# %%
electrostatic_potential_vec
# Out:
# array([-10. ,  -9.8,  -9.6,  -9.4,  -9.2,  -9. ,  -8.8,  -8.6,  -8.4,
#         -8.2,  -8. ,  -7.8,  -7.6,  -7.4,  -7.2,  -7. ,  -6.8,  -6.6,
#         -6.4,  -6.2,  -6. ,  -5.8,  -5.6,  -5.4,  -5.2,  -5. ,  -4.8,
#         -4.6,  -4.4,  -4.2,  -4. ,  -3.8,  -3.6,  -3.4,  -3.2,  -3. ,
#         -2.8,  -2.6,  -2.4,  -2.2,  -2. ,  -1.8,  -1.6,  -1.4,  -1.2,
#         -1. ,  -0.8,  -0.6,  -0.4,  -0.2,   0. ,   0.2,   0.4,   0.6,
#          0.8,   1. ,   1.2,   1.4,   1.6,   1.8,   2. ,   2.2,   2.4,
#          2.6,   2.8,   3. ,   3.2,   3.4,   3.6,   3.8,   4. ,   4.2,
#          4.4,   4.6,   4.8,   5. ,   5.2,   5.4,   5.6,   5.8,   6. ,
#          6.2,   6.4,   6.6,   6.8,   7. ,   7.2,   7.4,   7.6,   7.8,
#          8. ,   8.2,   8.4,   8.6,   8.8,   9. ,   9.2,   9.4,   9.6,
#          9.8,  10. ,  10. ,   9.8,   9.6,   9.4,   9.2,   9. ,   8.8,
#          8.6,   8.4,   8.2,   8. ,   7.8,   7.6,   7.4,   7.2,   7. ,
# ...

# %% [markdown]
# Now do the thin film problem:

# %%
import os
import subprocess
import numpy as np


file_directory = '/home/john/Hysteresis/'
output_file_directory = '/home/john/Hysteresis/testThinfilm/'


#construct the field pattern. Note that -10.0 = 0.1 nN/aC = 1000 kV/cm


electrostatic_potential_vec1 = np.linspace(-1.0, 1.0, 51 );
electrostatic_potential_vec2 = np.linspace(1.0, -1.0, 51 );

electrostatic_potential_vec = np.concatenate((electrostatic_potential_vec1, electrostatic_potential_vec2), axis = 0)

#First file (index 0) is the solve on full TDLGD.
for t in range(0,len(electrostatic_potential_vec)):
    infile = open('/home/john/Hysteresis/PTOepitaxy_09_50_10_10_G1_Pole-def.i')
    outfile = open('/home/john/Hysteresis/testThinfilm/PTOepitaxy_09_50_10_10_G1_Pole-'+repr(t)+'.i', 'w')
    replacements = {
        'file = out_PTOthinfilm_09_50_10_10_defH.e':'file = out_PTOthinfilm_09_50_10_10_H'+repr(t)+'.e',
        'value = def':'value = %s' % electrostatic_potential_vec[t],
        'file_base = out_PTOthinfilm_09_50_10_10_def':'file_base = out_PTOthinfilm_09_50_10_10_'+repr(t)
    }
    for line in infile:
        for src, target in replacements.iteritems():
            line = line.replace(src, target)
        outfile.write(line)
    infile.close()
    outfile.close()
    
for k in range(0,len(electrostatic_potential_vec)-1):
    infile = open('/home/john/Hysteresis/PTOepitaxy_09_50_10_10_G1_NoiseStep-def.i')
    outfile = open('/home/john/Hysteresis/testThinfilm/PTOepitaxy_09_50_10_10_G1_NoiseStep-'+repr(k+1)+'.i', 'w')
    replacements = {
        'file = out_PTOthinfilm_09_50_10_10_def.e':'file = out_PTOthinfilm_09_50_10_10_'+repr(k)+'.e',
        'file_base = out_PTOthinfilm_09_50_10_10_defH':'file_base = out_PTOthinfilm_09_50_10_10_H'+repr(k+1)
    }
    for line in infile:
        for src, target in replacements.iteritems():
            line = line.replace(src, target)
        outfile.write(line)
    infile.close()
    outfile.close()
    
    
#Make sure first file solves TDLGD with the original mesh.
infile = open('/home/john/Hysteresis/testThinfilm/PTOepitaxy_09_50_10_10_G1_Pole-0.i')
outfile = open('/home/john/Hysteresis/testThinfilm/PTOepitaxy_09_50_10_10_G1_Pole-0temp.i', 'w')
replacements = {
        "initial_from_file_timestep = 'LATEST'":"",
        "initial_from_file_var = polar_x":"[./InitialCondition]      type = RandomIC      min = -0.5e-5      max = 0.5e-5      seed = 1    [../]",
        "initial_from_file_var = polar_y":"[./InitialCondition]      type = RandomIC      min = -0.5e-5      max = 0.5e-5      seed = 1    [../]",
        "initial_from_file_var = polar_z":"[./InitialCondition]      type = RandomIC      min = -0.5e-5      max = 0.5e-5      seed = 1    [../]",
        "initial_from_file_var = potential_int":"[./InitialCondition]      type = RandomIC      min = -0.5e-5      max = 0.5e-5      seed = 1    [../]",
        "initial_from_file_var = disp_x":"",
        "initial_from_file_var = disp_y":"",
        "initial_from_file_var = disp_z":"",
        "initial_from_file_var = stress_xx_elastic":"",
        "initial_from_file_var = stress_xy_elastic":"",
        "initial_from_file_var = stress_xz_elastic":"",
        "initial_from_file_var = stress_yy_elastic":"",
        "initial_from_file_var = stress_yz_elastic":"",
        "initial_from_file_var = stress_zz_elastic":"",
        "initial_from_file_var = strain_xx_elastic":"",
        "initial_from_file_var = strain_xy_elastic":"",
        "initial_from_file_var = strain_xz_elastic":"",
        "initial_from_file_var = strain_yy_elastic":"",
        "initial_from_file_var = strain_yz_elastic":"",
        "initial_from_file_var = strain_zz_elastic":"",
        'file = out_PTOthinfilm_09_50_10_10_H0.e':'file = exodus_thinfilm_test_09_50_10_10.e'
    }
for line in infile:
    for src, target in replacements.iteritems():
        line = line.replace(src, target)
    outfile.write(line)
infile.close()
outfile.close()

#remove and rename the first file.
os.remove('/home/john/Hysteresis/testThinfilm/PTOepitaxy_09_50_10_10_G1_Pole-0.i')

os.rename("/home/john/Hysteresis/testThinfilm/PTOepitaxy_09_50_10_10_G1_Pole-0temp.i","/home/john/Hysteresis/testThinfilm/PTOepitaxy_09_50_10_10_G1_Pole-0.i")
